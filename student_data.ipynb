# %% [markdown]
# # Student Data
# This notebook analysis student data

# %%
# numbers = [5, 12, 19, 23, 34, 45, 56, 67, 78, 89, 
#            90, 102, 115, 128, 139, 150, 162, 174, 185, 199]

# print(numbers* 2)

# import numpy as np

# grades = np.array(numbers)
# print(grades)

# multiplyBy2=grades * 2
# print(grades.shape)

# print(multiplyBy2[2])
# print(multiplyBy2.mean())


# # destructuring
# student_data=np.array([numbers,multiplyBy2])
# print(student_data[0][1])

# # average 
# avg_study= student_data[0].mean()
# avg_grades=student_data[1].mean()

# print(f'Averade Study time :{avg_study}\n Average grades :{avg_grades}' )

# import pandas as pd
 
# df_students= pd.DataFrame({"names":[
#     "Ayaan", "Zoya", "Daniel", "Fatima", "Ahmed",
#     "Sara", "Ali", "Hira", "Omar", "Maryam",
#     "Hamza", "Aisha", "Usman", "Noor", "Bilal",
#     "Sana", "Rehan", "Mehak", "Saad", "Laiba"
# ],"study_hours": student_data[0],
# "grades":student_data[1]}) 
# print (df_students)

# print(numbers[0:4])
# print(df_students.loc[5])
# userData= input("what is your age?")



# print(student_data[0].mean())



# sum = grades.sum()
# print(sum/2)


 
# names={"Ayaan", "Zoya", "Daniel", "Fatima", "Ahmed",
#     "Sara", "Ali", "Hira", "Omar", "Maryam",
#     "Hamza", "Aisha", "Usman", "Noor", "Bilal",
#     "Sana", "Rehan", "Mehak", "Saad", "Laiba"}
# name=  {"Hamza"}

# print(names.issuperset(name))


# print(dir(names))
# print(names[::3]) #every 3rd name
# names.append("tayyaba")
# names.count("tayyaba")
# names.reverse()
# names.sort()
# names.remove("Laiba")
# names.copy()
# print(len(names))
# names[0]="tayyaba"
# names.clear()
# for n in names:
#   print(n.lower())
#   print(n.upper())
#   print(names[::3])

# print(names)

# a= 0
# b=4
# c=9
# print(b and a)
# print(a or c)


# Write a Python statement using the not operator that prints:

# "Stay home" if it’s raining and you don’t have an umbrella

# "Go outside" otherwise


# is_raining = False
# have_umbrella = False


# if not(is_raining) and not(have_umbrella):

#     print("You can go with umbrella" )
# elif( is_raining and not(have_umbrella)):
#     print("You can also go")



    
# 2. Even or Odd (Without Using if-else)

# Take an integer input and check if it’s even or odd without using if or else (hint: use boolean logic or operators).


userInput = input("Enter an integer: ")

if userInput == "":
    print("Please enter a valid integer.")
else:
    userInput = int(userInput)
    even = userInput % 2 == 0
    print("Even") if even else print("Odd")
# Out:
# Please enter a valid integer.
